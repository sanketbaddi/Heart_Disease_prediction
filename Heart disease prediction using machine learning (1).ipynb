# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import os
#print(os.listdir())

import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv(r"C:\Users\91944\Downloads\heart.csv")

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (1025, 14)

# %%
dataset.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
dataset.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 491   57    1   2       150   168    0        1      174      0      1.6
# 492   64    1   2       125   309    0        1      131      1      1.8
# 241   67    1   2       152   212    0        0      150      0      0.8
# 513   54    1   0       110   206    0        0      108      1      0.0
# 164   56    1   0       125   249    1        0      144      1      1.2
#
#      slope  ca  thal  target
# 491      2   0     2       1
# 492      1   0     3       0
# 241      1   0     3       0
# 513      1   1     2       0
# 164      1   1     2       0

# %%
dataset.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure"," serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved","exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment","number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]



for i in range(len(info)):
    print(dataset.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
dataset["target"].describe()
# Out:
# count    1025.000000
# mean        0.513171
# std         0.500070
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
dataset["target"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
print(dataset.corr()["target"].abs().sort_values(ascending=False))
# Out:
# target      1.000000
# oldpeak     0.438441
# exang       0.438029
# cp          0.434854
# thalach     0.422895
# ca          0.382085
# slope       0.345512
# thal        0.337838
# sex         0.279501
# age         0.229324
# trestbps    0.138772
# restecg     0.134468
# chol        0.099966
# fbs         0.041164
# Name: target, dtype: float64

# %%
y=dataset["target"]
sns.countplot(y)

target_temp=dataset.target.value_counts()
print(target_temp)
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
print("Percentage of patients without heart problem:"+str(round(target_temp[0]*100/1025,2)))
print("Percentage of patients with heart problem:"+str(round(target_temp[1]*100/1025,2)))
# Out:
# Percentage of patients without heart problem:48.68
# Percentage of patients with heart problem:51.32

# %%
dataset.sex.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#z=dataset.sex
#sns.countplot(z)
sns.barplot(dataset.sex,y)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='target'>

# %%
import seaborn as sns
sns.set()
sns.pairplot(dataset,hue='target',size=2.5)
plt.show()

# %%
dataset.cp.unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
sns.barplot(dataset.cp,y)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='target'>

# %%
dataset.fbs.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.barplot(dataset.fbs,y)
# Out:
# <AxesSubplot:xlabel='fbs', ylabel='target'>

# %%
dataset.restecg.unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
sns.barplot(dataset.restecg,y)
# Out:
# <AxesSubplot:xlabel='restecg', ylabel='target'>

# %%
dataset.exang.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.barplot(dataset.exang,y)
# Out:
# <AxesSubplot:xlabel='exang', ylabel='target'>

# %%
dataset.slope.unique()
# Out:
# array([2, 0, 1], dtype=int64)

# %%
sns.barplot(dataset.slope,y)
# Out:
# <AxesSubplot:xlabel='slope', ylabel='target'>

# %%
dataset.ca.unique()
# Out:
# array([2, 0, 1, 3, 4], dtype=int64)

# %%
sns.countplot(dataset.ca)
# Out:
# <AxesSubplot:xlabel='ca', ylabel='count'>

# %%
sns.barplot(dataset.ca,y)
# Out:
# <AxesSubplot:xlabel='ca', ylabel='target'>

# %%
dataset.thal.unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
sns.barplot(dataset.thal,y)
# Out:
# <AxesSubplot:xlabel='thal', ylabel='target'>

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\91944\anaconda3\envs\pandas\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\91944\anaconda3\envs\pandas\lib\site-packages (from scikit-learn) (1.20.3)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\91944\anaconda3\envs\pandas\lib\site-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\91944\anaconda3\envs\pandas\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\91944\anaconda3\envs\pandas\lib\site-packages (from scikit-learn) (1.6.2)

# %%
from sklearn.model_selection import train_test_split
predictors = dataset.drop("target",axis=1)
target = dataset["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (820, 13)

# %%
X_test.shape
# Out:
# (205, 13)

# %%
Y_train.shape
# Out:
# (820,)

# %%
Y_test.shape
# Out:
# (205,)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,Y_train)
Y_pred_lr=lr.predict(X_test)

# %%
Y_pred_lr.shape
# Out:
# (205,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)
print("the accuracy score achieved using logistic regression is:"+str(score_lr)+"%")
# Out:
# the accuracy score achieved using logistic regression is:86.34%

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(X_train,Y_train)
Y_pred_nb= nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (205,)

# %%
score_nb=round(accuracy_score(Y_pred_nb,Y_test)*100,2)
print("the accuracy score achieved using Naive Bayes is:"+str(score_nb)+"%")
# Out:
# the accuracy score achieved using Naive Bayes is:85.37%

# %%
from sklearn import svm
sv= svm.SVC(kernel='linear')
sv.fit(X_train,Y_train)
Y_pred_svm=sv.predict(X_test)

# %%
Y_pred_svm.shape
# Out:
# (205,)

# %%
score_svm= round(accuracy_score(Y_pred_svm,Y_test)*100,2)
print("the accuracy score achieved using Support Vector Machine is:"+str(score_svm)+"%")
# Out:
# the accuracy score achieved using Support Vector Machine is:83.9%

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)

# %%
score_knn=round(accuracy_score(Y_pred_knn,Y_test)*100,2)
print("the accuracy score achieved using KNN is:"+str(score_knn)+"%")
# Out:
# the accuracy score achieved using KNN is:72.2%

# %%
#from sklearn.preprocessing import StandardScaler
#scaler=StandardScaler()
#scaler.fit(dataset.drop('target',axis=1))
#scaled_features=scaler.transform(dataset.drop('target',axis=1))
#dataset_feat=pd.DataFrame(scaled_features,columns=dataset.columns[:-1])

# %%
#from sklearn.model_selection import cross_val_score
#accuracy_r1=[]
#for i in range(0,40):
    #knn=KNeighborsClassifier(n_neighbors=i)
    #score=cross_val_score(knn,dataset_feat,dataset['target'],cv=10)
    #accuracy_r1.append(score.mean())

# %%
from sklearn.tree import DecisionTreeClassifier
max_accuracy=0

for x in range(200):
    dt=DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt=dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy=current_accuracy
        best_x=x
        
print(max_accuracy)
print(best_x)
dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)
# Out:
# 100.0
# 0

# %%
score_dt=round(accuracy_score(Y_pred_dt,Y_test)*100,2)
print("the accuracy score achieved using Decision Tree is:"+str(score_dt)+"%")
# Out:
# the accuracy score achieved using Decision Tree is:100.0%

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0


for x in range(2000):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
print(max_accuracy)
print(best_x)

rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)
# Out:
# 100.0
# 0

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)

print("The accuracy score achieved using Random Forest is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Random Forest is: 100.0 %

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.6.1-py3-none-win_amd64.whl (125.4 MB)
# Requirement already satisfied: numpy in c:\users\91944\anaconda3\envs\pandas\lib\site-packages (from xgboost) (1.20.3)
# Requirement already satisfied: scipy in c:\users\91944\anaconda3\envs\pandas\lib\site-packages (from xgboost) (1.6.2)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.6.1

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 100.0 %

# %%
scores = [score_lr,score_nb,score_svm,score_knn,score_dt,score_rf,score_xgb]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","K-Nearest Neighbors","Decision Tree","Random Forest","XGBoost"]

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

sns.barplot(algorithms,scores)
# Out:
# <AxesSubplot:xlabel='Algorithms', ylabel='Accuracy score'>
